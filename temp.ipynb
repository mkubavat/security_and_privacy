# %%
import os
import sys
from subprocess import check_output

def decrypt_byte(ciphertext, y_n, y_n_minus_1):
    for i in range(256):
        r = os.urandom(15) + bytes([i])
        modified_ciphertext = y_n_minus_1 + r + y_n
        with open("temp_cipher.bin", "wb") as f:
            f.write(modified_ciphertext)
        result = check_output(['python3', 'oracle.py', 'temp_cipher.bin']).strip()
        print(f"Testing byte value: {i}, Result: {result}")  # Debug print
        if result == b'1':
            return i
    raise Exception("Failed to decrypt the byte")

def decrypt_block(ciphertext, y_n, y_n_minus_1):
    decrypted_bytes = bytearray(16)
    derived_values = bytearray(16)
    derived_values[15] = decrypt_byte(ciphertext, y_n, y_n_minus_1)
    decrypted_bytes[15] = derived_values[15] ^ y_n_minus_1[15]

    for k in range(14, -1, -1):
        padding_value = 17 - (k + 1)
        r = (os.urandom(k) + bytes([derived_values[k+1] ^ padding_value]) +
             bytes([derived_values[j] ^ padding_value for j in range(k+1, 16)]))
        modified_ciphertext = y_n_minus_1 + r + y_n
        with open("temp_cipher.bin", "wb") as f:
            f.write(modified_ciphertext)
        result = check_output(['python3', 'oracle.py', 'temp_cipher.bin']).strip()
        print(f"Decrypting byte {k}, Result: {result}")  # Debug print
        if result == b'1':
            derived_values[k] = r[k] ^ padding_value
            decrypted_bytes[k] = derived_values[k] ^ y_n_minus_1[k]
    return decrypted_bytes

def decrypt(ciphertext):
    blocks = [ciphertext[i:i+16] for i in range(0, len(ciphertext), 16)]
    iv = blocks[0]  # The IV should not be decrypted but used to decrypt the first block
    plaintext = b''

    # Start decryption from the second block
    for i in range(1, len(blocks)):
        plaintext += decrypt_block(ciphertext, blocks[i], blocks[i-1])

    # Assume the last byte indicates padding length and check for valid padding
    pad_len = plaintext[-1]
    if pad_len < 1 or pad_len > 16:
        raise ValueError("Invalid padding length.")
    if all(plaintext[-j] == pad_len for j in range(1, pad_len+1)):
        return plaintext[:-pad_len]
    else:
        raise ValueError("Padding does not match expected format.")
    
def decrypt_test_block(ciphertext, y_n, y_n_minus_1):
    for i in range(256):
        r = os.urandom(15) + bytes([i])
        modified_ciphertext = y_n_minus_1 + r + y_n
        result = check_output(['python3', 'oracle.py', modified_ciphertext]).strip()
        if result == '1':
            return i, modified_ciphertext
    return None, None

# %%
with open("ciphertext", "rb") as file:
        ciphertext = file.read()
    
if len(ciphertext) % 16 != 0 or len(ciphertext) < 32:
    print("Ciphertext must be a multiple of 16 bytes and at least 32 bytes.")
    sys.exit(1)
    
try:
    plaintext = decrypt(ciphertext)
    plaintext_decoded = plaintext.decode('ascii')  # Decode bytes to string for ASCII plaintext

    # Now, write the decrypted plaintext to a file
    with open("plaintext.txt", "w") as text_file:
        text_file.write(plaintext_decoded)
    print("Decrypted plaintext saved to plaintext.txt")
except ValueError as e:
    print(str(e))
# Out:
# Testing byte value: 0, Result: b'0'
# Testing byte value: 1, Result: b'0'
# Testing byte value: 2, Result: b'0'
# Testing byte value: 3, Result: b'0'
# Testing byte value: 4, Result: b'0'
# Testing byte value: 5, Result: b'0'
# Testing byte value: 6, Result: b'0'
# Testing byte value: 7, Result: b'0'
# Testing byte value: 8, Result: b'0'
# Testing byte value: 9, Result: b'0'
# Testing byte value: 10, Result: b'0'
# Testing byte value: 11, Result: b'0'
# Testing byte value: 12, Result: b'0'
# Testing byte value: 13, Result: b'0'
# Testing byte value: 14, Result: b'0'
# Testing byte value: 15, Result: b'0'
# Testing byte value: 16, Result: b'0'
# Testing byte value: 17, Result: b'0'
# Testing byte value: 18, Result: b'0'
# Testing byte value: 19, Result: b'0'
# Testing byte value: 20, Result: b'0'
# Testing byte value: 21, Result: b'0'
# Testing byte value: 22, Result: b'0'
# Testing byte value: 23, Result: b'0'
# Testing byte value: 24, Result: b'0'
# Testing byte value: 25, Result: b'0'
# Testing byte value: 26, Result: b'0'
# Testing byte value: 27, Result: b'0'
# Testing byte value: 28, Result: b'0'
# Testing byte value: 29, Result: b'0'
# Testing byte value: 30, Result: b'0'
# Testing byte value: 31, Result: b'0'
# Testing byte value: 32, Result: b'0'
# Testing byte value: 33, Result: b'0'
# Testing byte value: 34, Result: b'0'
# Testing byte value: 35, Result: b'0'
# Testing byte value: 36, Result: b'0'
# Testing byte value: 37, Result: b'0'
# Testing byte value: 38, Result: b'0'
# Testing byte value: 39, Result: b'0'
# Testing byte value: 40, Result: b'0'
# Testing byte value: 41, Result: b'0'
# Testing byte value: 42, Result: b'0'
# Testing byte value: 43, Result: b'0'
# Testing byte value: 44, Result: b'0'
# Testing byte value: 45, Result: b'0'
# Testing byte value: 46, Result: b'0'
# Testing byte value: 47, Result: b'0'
# Testing byte value: 48, Result: b'0'
# Testing byte value: 49, Result: b'0'
# Testing byte value: 50, Result: b'0'
# Testing byte value: 51, Result: b'0'
# Testing byte value: 52, Result: b'0'
# Testing byte value: 53, Result: b'0'
# Testing byte value: 54, Result: b'0'
# Testing byte value: 55, Result: b'0'
# Testing byte value: 56, Result: b'0'
# Testing byte value: 57, Result: b'1'
# Decrypting byte 14, Result: b'0'
# Decrypting byte 13, Result: b'0'
# Decrypting byte 12, Result: b'0'
# Decrypting byte 11, Result: b'0'
# Decrypting byte 10, Result: b'0'
# Decrypting byte 9, Result: b'0'
# Decrypting byte 8, Result: b'0'
# Decrypting byte 7, Result: b'0'
# Decrypting byte 6, Result: b'0'
# Decrypting byte 5, Result: b'0'
# Decrypting byte 4, Result: b'0'
# Decrypting byte 3, Result: b'0'
# Decrypting byte 2, Result: b'0'
# Decrypting byte 1, Result: b'0'
# Decrypting byte 0, Result: b'0'
# Testing byte value: 0, Result: b'0'
# Testing byte value: 1, Result: b'0'
# Testing byte value: 2, Result: b'0'
# Testing byte value: 3, Result: b'0'
# Testing byte value: 4, Result: b'0'
# Testing byte value: 5, Result: b'0'
# Testing byte value: 6, Result: b'0'
# Testing byte value: 7, Result: b'0'
# Testing byte value: 8, Result: b'0'
# Testing byte value: 9, Result: b'0'
# Testing byte value: 10, Result: b'0'
# Testing byte value: 11, Result: b'0'
# Testing byte value: 12, Result: b'0'
# Testing byte value: 13, Result: b'0'
# Testing byte value: 14, Result: b'0'
# Testing byte value: 15, Result: b'0'
# Testing byte value: 16, Result: b'0'
# Testing byte value: 17, Result: b'0'
# Testing byte value: 18, Result: b'0'
# Testing byte value: 19, Result: b'0'
# Testing byte value: 20, Result: b'0'
# Testing byte value: 21, Result: b'0'
# Testing byte value: 22, Result: b'0'
# Testing byte value: 23, Result: b'0'
# Testing byte value: 24, Result: b'0'
# Testing byte value: 25, Result: b'0'
# Testing byte value: 26, Result: b'0'
# Testing byte value: 27, Result: b'0'
# Testing byte value: 28, Result: b'0'
# Testing byte value: 29, Result: b'0'
# Testing byte value: 30, Result: b'0'
# Testing byte value: 31, Result: b'0'
# Testing byte value: 32, Result: b'0'
# Testing byte value: 33, Result: b'0'
# Testing byte value: 34, Result: b'0'
# Testing byte value: 35, Result: b'0'
# Testing byte value: 36, Result: b'0'
# Testing byte value: 37, Result: b'0'
# Testing byte value: 38, Result: b'0'
# Testing byte value: 39, Result: b'0'
# Testing byte value: 40, Result: b'0'
# Testing byte value: 41, Result: b'0'
# Testing byte value: 42, Result: b'0'
# Testing byte value: 43, Result: b'0'
# Testing byte value: 44, Result: b'0'
# Testing byte value: 45, Result: b'0'
# Testing byte value: 46, Result: b'0'
# Testing byte value: 47, Result: b'0'
# Testing byte value: 48, Result: b'0'
# Testing byte value: 49, Result: b'0'
# Testing byte value: 50, Result: b'0'
# Testing byte value: 51, Result: b'0'
# Testing byte value: 52, Result: b'0'
# Testing byte value: 53, Result: b'0'
# Testing byte value: 54, Result: b'0'
# Testing byte value: 55, Result: b'0'
# Testing byte value: 56, Result: b'0'
# Testing byte value: 57, Result: b'0'
# Testing byte value: 58, Result: b'0'
# Testing byte value: 59, Result: b'0'
# Testing byte value: 60, Result: b'0'
# Testing byte value: 61, Result: b'0'
# Testing byte value: 62, Result: b'0'
# Testing byte value: 63, Result: b'0'
# Testing byte value: 64, Result: b'0'
# Testing byte value: 65, Result: b'0'
# Testing byte value: 66, Result: b'0'
# Testing byte value: 67, Result: b'0'
# Testing byte value: 68, Result: b'0'
# Testing byte value: 69, Result: b'0'
# Testing byte value: 70, Result: b'0'
# Testing byte value: 71, Result: b'0'
# Testing byte value: 72, Result: b'0'
# Testing byte value: 73, Result: b'0'
# Testing byte value: 74, Result: b'0'
# Testing byte value: 75, Result: b'0'
# Testing byte value: 76, Result: b'0'
# Testing byte value: 77, Result: b'0'
# Testing byte value: 78, Result: b'0'
# Testing byte value: 79, Result: b'0'
# Testing byte value: 80, Result: b'0'
# Testing byte value: 81, Result: b'0'
# Testing byte value: 82, Result: b'0'
# Testing byte value: 83, Result: b'0'
# Testing byte value: 84, Result: b'0'
# Testing byte value: 85, Result: b'0'
# Testing byte value: 86, Result: b'0'
# Testing byte value: 87, Result: b'0'
# Testing byte value: 88, Result: b'0'
# Testing byte value: 89, Result: b'0'
# Testing byte value: 90, Result: b'0'
# Testing byte value: 91, Result: b'0'
# Testing byte value: 92, Result: b'0'
# Testing byte value: 93, Result: b'0'
# Testing byte value: 94, Result: b'0'
# Testing byte value: 95, Result: b'0'
# Testing byte value: 96, Result: b'0'
# Testing byte value: 97, Result: b'0'
# Testing byte value: 98, Result: b'0'
# Testing byte value: 99, Result: b'0'
# Testing byte value: 100, Result: b'0'
# Testing byte value: 101, Result: b'0'
# Testing byte value: 102, Result: b'0'
# Testing byte value: 103, Result: b'0'
# Testing byte value: 104, Result: b'0'
# Testing byte value: 105, Result: b'0'
# Testing byte value: 106, Result: b'0'
# Testing byte value: 107, Result: b'0'
# Testing byte value: 108, Result: b'0'
# Testing byte value: 109, Result: b'0'
# Testing byte value: 110, Result: b'0'
# Testing byte value: 111, Result: b'0'
# Testing byte value: 112, Result: b'0'
# Testing byte value: 113, Result: b'0'
# Testing byte value: 114, Result: b'0'
# Testing byte value: 115, Result: b'0'
# Testing byte value: 116, Result: b'0'
# Testing byte value: 117, Result: b'0'
# Testing byte value: 118, Result: b'0'
# Testing byte value: 119, Result: b'0'
# Testing byte value: 120, Result: b'0'
# Testing byte value: 121, Result: b'0'
# Testing byte value: 122, Result: b'0'
# Testing byte value: 123, Result: b'0'
# Testing byte value: 124, Result: b'0'
# Testing byte value: 125, Result: b'0'
# Testing byte value: 126, Result: b'0'
# Testing byte value: 127, Result: b'0'
# Testing byte value: 128, Result: b'0'
# Testing byte value: 129, Result: b'0'
# Testing byte value: 130, Result: b'0'
# Testing byte value: 131, Result: b'0'
# Testing byte value: 132, Result: b'0'
# Testing byte value: 133, Result: b'0'
# Testing byte value: 134, Result: b'0'
# Testing byte value: 135, Result: b'0'
# Testing byte value: 136, Result: b'0'
# Testing byte value: 137, Result: b'0'
# Testing byte value: 138, Result: b'0'
# Testing byte value: 139, Result: b'0'
# Testing byte value: 140, Result: b'0'
# Testing byte value: 141, Result: b'0'
# Testing byte value: 142, Result: b'0'
# Testing byte value: 143, Result: b'0'
# Testing byte value: 144, Result: b'0'
# Testing byte value: 145, Result: b'0'
# Testing byte value: 146, Result: b'0'
# Testing byte value: 147, Result: b'0'
# Testing byte value: 148, Result: b'0'
# Testing byte value: 149, Result: b'0'
# Testing byte value: 150, Result: b'0'
# Testing byte value: 151, Result: b'0'
# Testing byte value: 152, Result: b'0'
# Testing byte value: 153, Result: b'0'
# Testing byte value: 154, Result: b'0'
# Testing byte value: 155, Result: b'0'
# Testing byte value: 156, Result: b'0'
# Testing byte value: 157, Result: b'0'
# Testing byte value: 158, Result: b'0'
# Testing byte value: 159, Result: b'0'
# Testing byte value: 160, Result: b'0'
# Testing byte value: 161, Result: b'0'
# Testing byte value: 162, Result: b'0'
# Testing byte value: 163, Result: b'0'
# Testing byte value: 164, Result: b'0'
# Testing byte value: 165, Result: b'0'
# Testing byte value: 166, Result: b'0'
# Testing byte value: 167, Result: b'0'
# Testing byte value: 168, Result: b'0'
# Testing byte value: 169, Result: b'0'
# Testing byte value: 170, Result: b'0'
# Testing byte value: 171, Result: b'0'
# Testing byte value: 172, Result: b'0'
# Testing byte value: 173, Result: b'0'
# Testing byte value: 174, Result: b'0'
# Testing byte value: 175, Result: b'0'
# Testing byte value: 176, Result: b'0'
# Testing byte value: 177, Result: b'0'
# Testing byte value: 178, Result: b'0'
# Testing byte value: 179, Result: b'0'
# Testing byte value: 180, Result: b'0'
# Testing byte value: 181, Result: b'0'
# Testing byte value: 182, Result: b'0'
# Testing byte value: 183, Result: b'0'
# Testing byte value: 184, Result: b'0'
# Testing byte value: 185, Result: b'0'
# Testing byte value: 186, Result: b'0'
# Testing byte value: 187, Result: b'0'
# Testing byte value: 188, Result: b'0'
# Testing byte value: 189, Result: b'0'
# Testing byte value: 190, Result: b'0'
# Testing byte value: 191, Result: b'0'
# Testing byte value: 192, Result: b'0'
# Testing byte value: 193, Result: b'0'
# Testing byte value: 194, Result: b'0'
# Testing byte value: 195, Result: b'0'
# Testing byte value: 196, Result: b'0'
# Testing byte value: 197, Result: b'0'
# Testing byte value: 198, Result: b'0'
# Testing byte value: 199, Result: b'0'
# Testing byte value: 200, Result: b'0'
# Testing byte value: 201, Result: b'0'
# Testing byte value: 202, Result: b'0'
# Testing byte value: 203, Result: b'0'
# Testing byte value: 204, Result: b'0'
# Testing byte value: 205, Result: b'0'
# Testing byte value: 206, Result: b'0'
# Testing byte value: 207, Result: b'0'
# Testing byte value: 208, Result: b'0'
# Testing byte value: 209, Result: b'0'
# Testing byte value: 210, Result: b'0'
# Testing byte value: 211, Result: b'0'
# Testing byte value: 212, Result: b'0'
# Testing byte value: 213, Result: b'0'
# Testing byte value: 214, Result: b'0'
# Testing byte value: 215, Result: b'0'
# Testing byte value: 216, Result: b'0'
# Testing byte value: 217, Result: b'0'
# Testing byte value: 218, Result: b'0'
# Testing byte value: 219, Result: b'0'
# Testing byte value: 220, Result: b'0'
# Testing byte value: 221, Result: b'0'
# Testing byte value: 222, Result: b'0'
# Testing byte value: 223, Result: b'0'
# Testing byte value: 224, Result: b'0'
# Testing byte value: 225, Result: b'0'
# Testing byte value: 226, Result: b'0'
# Testing byte value: 227, Result: b'0'
# Testing byte value: 228, Result: b'0'
# Testing byte value: 229, Result: b'0'
# Testing byte value: 230, Result: b'0'
# Testing byte value: 231, Result: b'0'
# Testing byte value: 232, Result: b'0'
# Testing byte value: 233, Result: b'0'
# Testing byte value: 234, Result: b'0'
# Testing byte value: 235, Result: b'0'
# Testing byte value: 236, Result: b'0'
# Testing byte value: 237, Result: b'0'
# Testing byte value: 238, Result: b'0'
# Testing byte value: 239, Result: b'0'
# Testing byte value: 240, Result: b'0'
# Testing byte value: 241, Result: b'0'
# Testing byte value: 242, Result: b'0'
# Testing byte value: 243, Result: b'0'
# Testing byte value: 244, Result: b'0'
# Testing byte value: 245, Result: b'0'
# Testing byte value: 246, Result: b'1'
# Decrypting byte 14, Result: b'0'
# Decrypting byte 13, Result: b'0'
# Decrypting byte 12, Result: b'0'
# Decrypting byte 11, Result: b'0'
# Decrypting byte 10, Result: b'0'
# Decrypting byte 9, Result: b'0'
# Decrypting byte 8, Result: b'0'
# Decrypting byte 7, Result: b'0'
# Decrypting byte 6, Result: b'0'
# Decrypting byte 5, Result: b'0'
# Decrypting byte 4, Result: b'0'
# Decrypting byte 3, Result: b'0'
# Decrypting byte 2, Result: b'0'
# Decrypting byte 1, Result: b'0'
# Decrypting byte 0, Result: b'0'
# Padding does not match expected format.

# %%
# Simplified decryption function to test smaller segments and ensure correct block passing
iv_bytes = b'CMPT 403 Test IV'

# Testing a smaller part to debug and optimize
test_byte, test_ciphertext = decrypt_test_block(ciphertext[16:32], ciphertext[16:32], b'CMPT 403 Test IV')
test_byte, test_ciphertext

# Manually construct a block with correct and incorrect padding
correct_padding_block = ciphertext[16:32]  # assuming this block ends with correct padding
incorrect_padding_block = correct_padding_block[:-1] + bytes([correct_padding_block[-1] ^ 1])  # Flip last byte

# Test the oracle with both
oracle_result_correct = check_output(['python3', 'oracle.py', iv_bytes + correct_padding_block]).strip()
oracle_result_incorrect = check_output(['python3', 'oracle.py', iv_bytes + correct_padding_block]).strip()

oracle_result_correct, oracle_result_incorrect
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 5
#       2 iv_bytes = b'CMPT 403 Test IV'
#       4 # Testing a smaller part to debug and optimize
# ----> 5 test_byte, test_ciphertext = decrypt_test_block(ciphertext[16:32], ciphertext[16:32], b'CMPT 403 Test IV')
#       6 test_byte, test_ciphertext
#       8 # Manually construct a block with correct and incorrect padding
#
# Cell In[16], line 59, in decrypt_test_block(ciphertext, y_n, y_n_minus_1)
#      57 r = os.urandom(15) + bytes([i])
#      58 modified_ciphertext = y_n_minus_1 + r + y_n
# ---> 59 result = check_output(['python3', 'oracle.py', modified_ciphertext]).strip()
#      60 if result == '1':
#      61     return i, modified_ciphertext
#
# File /usr/lib/python3.10/subprocess.py:421, in check_output(timeout, *popenargs, **kwargs)
#     418         empty = b''
#     419     kwargs['input'] = empty
# --> 421 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     422            **kwargs).stdout
#
# File /usr/lib/python3.10/subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     500     kwargs['stdout'] = PIPE
#     501     kwargs['stderr'] = PIPE
# --> 503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
#     505         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /usr/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     967         if self.text_mode:
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#     982     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /usr/lib/python3.10/subprocess.py:1796, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1794     fds_to_keep = set(pass_fds)
#    1795     fds_to_keep.add(errpipe_write)
# -> 1796     self.pid = _posixsubprocess.fork_exec(
#    1797             args, executable_list,
#    1798             close_fds, tuple(sorted(map(int, fds_to_keep))),
#    1799             cwd, env_list,
#    1800             p2cread, p2cwrite, c2pread, c2pwrite,
#    1801             errread, errwrite,
#    1802             errpipe_read, errpipe_write,
#    1803             restore_signals, start_new_session,
#    1804             gid, gids, uid, umask,
#    1805             preexec_fn)
#    1806     self._child_created = True
#    1807 finally:
#    1808     # be sure the FD is closed no matter what
#
# ValueError: embedded null byte
